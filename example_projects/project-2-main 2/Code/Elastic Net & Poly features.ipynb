# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

from sklearn import metrics
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# %%
# Model 1 with df1 (simplest clean dataset- missings dropped, some columns dropped)

df1 = pd.read_csv('../datasets/df1.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0   Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  \
# 0           1  544  531379050           60        RL          43.0     11492
# 1           2  153  535304180           20        RL          68.0      7922
# 2           3  318  916386060           60        RL          73.0      9802
# 3           4  255  906425045           50        RL          82.0     14235
# 4           5  138  535126040           20        RL         137.0     16492
#
#   Street Lot Shape Land Contour  ... Enclosed Porch 3Ssn Porch Screen Porch  \
# 0   Pave       IR1          Lvl  ...              0          0            0
# 1   Pave       Reg          Lvl  ...              0          0            0
# 2   Pave       Reg          Lvl  ...              0          0            0
# 3   Pave       IR1          Lvl  ...              0          0            0
# 4   Pave       IR1          Lvl  ...              0          0            0
#
#   Pool Area Fence Misc Val  Mo Sold  Yr Sold  Sale Type  SalePrice
# 0         0   NaN        0        4     2009        WD      220000
# 1         0   NaN        0        1     2010        WD      109000
# 2         0   NaN        0        4     2010        WD      174000
# 3         0   NaN        0        3     2010        WD      138500
# 4         0   NaN        0        6     2010        WD      190000
#
# [5 rows x 75 columns]

# %%
df1.shape
# Out:
# (1598, 75)

# %%
df1_X = df1.drop(columns=['Unnamed: 0', 'Id', 'PID', 'SalePrice'])
df1_y = df1['SalePrice']

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(df1_X, df1_y, test_size= 0.2, random_state=24)

# %%
#Make lists of the numeric and string columns:
df1_str = list(df1_X.select_dtypes(include=['object']).columns)
df1_num = list(df1_X.select_dtypes(include=['int', 'float']).columns)

# %%
ct = ColumnTransformer([
    ('poly', PolynomialFeatures(include_bias=False), df1_num),
    ('scaler', StandardScaler(), df1_num), 
    ('oh', OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop='first'), df1_str)
], remainder='passthrough')  # 'passthrough' allows non-transformed columns to pass through

# Fit and transform the training data using the ColumnTransformer
X1_train_transformed = ct.fit_transform(X1_train)

# Transform the test data using the fitted ColumnTransformer
X1_test_transformed = ct.transform(X1_test)
# Out:
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [10, 17] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
lr = LinearRegression()
lr.fit(X1_train_transformed, y1_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Pre-processing:
# Referred to lesson 305 Feature Engineering
# ct = ColumnTransformer([
#     ('poly', PolynomialFeatures(include_bias=False), df1_num),
#     ('oh', OneHotEncoder(sparse_output=False, drop='first'), df1_str)
# ], remainder='drop')**

# %%
#lr = LinearRegression()
#lr.fit(df1_X, df1_y)

# %%
df5 = pd.read_csv('../datasets/df5.csv')

# %%
df5.head()
# Out:
#    Unnamed: 0  SalePrice   Id  Overall Qual  Gr Liv Area  Garage Area  \
# 0           0     130500  109             6         1479        475.0
# 1           1     220000  544             7         2122        559.0
# 2           2     109000  153             5         1057        246.0
# 3           3     174000  318             5         1444        400.0
# 4           4     138500  255             6         1445        484.0
#
#    Garage Cars  Total Bsmt SF  1st Flr SF  Year Built  ...  BsmtFin SF 1  \
# 0          2.0          725.0         725        1976  ...         533.0
# 1          2.0          913.0         913        1996  ...         637.0
# 2          1.0         1057.0        1057        1953  ...         731.0
# 3          2.0          384.0         744        2006  ...           0.0
# 4          2.0          676.0         831        1900  ...           0.0
#
#    Wood Deck SF  Neighborhood  Condition 1  Condition 2  Bldg Type  \
# 0             0        Sawyer         RRAe         Norm       1Fam
# 1             0       SawyerW         Norm         Norm       1Fam
# 2             0         NAmes         Norm         Norm       1Fam
# 3           100        Timber         Norm         Norm       1Fam
# 4             0       SawyerW         Norm         Norm       1Fam
#
#   House Style Overall Cond Functional Sale Type
# 0      2Story            8        Typ       WD
# 1      2Story            5        Typ       WD
# 2      1Story            7        Typ       WD
# 3      2Story            5        Typ       WD
# 4      1.5Fin            8        Typ       WD
#
# [5 rows x 24 columns]

# %% [markdown]
# # Regression with Polynomial Features

# %%
df6 = pd.read_csv('../datasets/df5.csv')

df6 = df6.dropna()

df6_X = df6.drop(columns=['Unnamed: 0', 'Id', 'SalePrice'])
df6_y = df6['SalePrice']

X6_train, X6_test, y6_train, y6_test = train_test_split(df6_X, df6_y, test_size= 0.2, random_state=24)

df6_train_str = list(X6_train.select_dtypes(include=['object']).columns)
df6_test_str = list(X6_test.select_dtypes(include=['object']).columns)
df6_train_num = list(X6_train.select_dtypes(include=['int', 'float']).columns)
df6_test_num = list(X6_test.select_dtypes(include=['int', 'float']).columns)

ct = ColumnTransformer([
    ('poly', PolynomialFeatures(include_bias=False), df6_train_num),
    ('scaler', StandardScaler(), df6_train_num),
    ('oh', OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop='first'), df6_train_str)
], remainder='passthrough')

# Fit and transform the training data using the ColumnTransformer
X6_train_transformed = ct.fit_transform(X6_train)

# Transform the test data using the fitted ColumnTransformer
X6_test_transformed = ct.transform(X6_test)

lr6 = LinearRegression()

lr6.fit(X6_train_transformed, y6_train)

r2_train = lr6.score(X6_train_transformed, y6_train)

r2_test = lr6.score(X6_test_transformed, y6_test)

y6_pred = lr6.predict(X6_test_transformed)

print(r2_train)
print(r2_test)
print(metrics.mean_squared_error(y6_test, y6_pred))
# Out:
# 0.9419309322015498
# 0.8988941760085423
# 679339772.2771369
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# # LASSO Regression

# %%
df6 = pd.read_csv('../datasets/df5.csv')
df6 = df6.dropna()
df6_X = df6.drop(columns=['Unnamed: 0', 'Id', 'SalePrice'])
df6_y = df6['SalePrice']
X6_train, X6_test, y6_train, y6_test = train_test_split(df6_X, df6_y, test_size=0.2, random_state=4)
df6_train_str = list(X6_train.select_dtypes(include=['object']).columns)
df6_test_str = list(X6_test.select_dtypes(include=['object']).columns)
df6_train_num = list(X6_train.select_dtypes(include=['int', 'float']).columns)
df6_test_num = list(X6_test.select_dtypes(include=['int', 'float']).columns)

# Create a ColumnTransformer with PolynomialFeatures, StandardScaler, and OneHotEncoder
ct = ColumnTransformer([
    ('poly', PolynomialFeatures(include_bias=False), df6_train_num),
    ('scaler', StandardScaler(), df6_train_num),
    ('oh', OneHotEncoder(sparse_output=False, drop='first'), df6_train_str)
], remainder='passthrough')

# Fit and transform the training data using the ColumnTransformer
X6_train_transformed = ct.fit_transform(X6_train)

# Transform the test data using the fitted ColumnTransformer
X6_test_transformed = ct.transform(X6_test)

# Create a Lasso model with regularization
lasso = Lasso(alpha=.01)  # You can adjust the alpha parameter as needed

# Fit the Lasso model to the training data
lasso.fit(X6_train_transformed, y6_train)

# Calculate the R-squared score on the training and test data
train_score = lasso.score(X6_train_transformed, y6_train)
test_score = lasso.score(X6_test_transformed, y6_test)

# Make predictions on the test data
y6_pred = lasso.predict(X6_test_transformed)

# Calculate the mean squared error
mse = metrics.mean_squared_error(y6_test, y6_pred)

print(f"Training R-squared: {train_score}")
print(f"Test R-squared: {test_score}")
print(f"Mean Squared Error: {mse}")
# Out:
# Training R-squared: 0.9418459116453659
# Test R-squared: 0.8214326923203195
# Mean Squared Error: 1003159696.248595
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.028e+11, tolerance: 1.041e+09
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # Regression Model with Polynomial Features and Elastic Net

# %% [markdown]
# *Credit to Lessons 403 and 406*

# %%
df6 = pd.read_csv('../datasets/df5.csv')
df6 = df6.dropna()
df6_X = df6.drop(columns=['Unnamed: 0', 'Id', 'SalePrice'])
df6_y = df6['SalePrice']
X6_train, X6_test, y6_train, y6_test = train_test_split(df6_X, df6_y, test_size=0.2, random_state=4)
df6_train_str = list(X6_train.select_dtypes(include=['object']).columns)
df6_test_str = list(X6_test.select_dtypes(include=['object']).columns)
df6_train_num = list(X6_train.select_dtypes(include=['int', 'float']).columns)
df6_test_num = list(X6_test.select_dtypes(include=['int', 'float']).columns)

# Create a ColumnTransformer with PolynomialFeatures, StandardScaler, and OneHotEncoder
ct = ColumnTransformer([
    ('poly', PolynomialFeatures(include_bias=False), df6_train_num),
    ('scaler', StandardScaler(), df6_train_num),
    ('oh', OneHotEncoder(sparse_output=False, drop='first'), df6_train_str)
], remainder='passthrough')

# Fit and transform the training data using the ColumnTransformer
X6_train_transformed = ct.fit_transform(X6_train)

# Transform the test data using the fitted ColumnTransformer
X6_test_transformed = ct.transform(X6_test)

# Create an ElasticNet model with regularization
elastic_net = ElasticNet(alpha=.01, l1_ratio=0.7)  

# Fit the ElasticNet model to the training data
elastic_net.fit(X6_train_transformed, y6_train)

# Calculate the R-squared score on the training and test data
train_score = elastic_net.score(X6_train_transformed, y6_train)
test_score = elastic_net.score(X6_test_transformed, y6_test)

# Make predictions on the test data
y6_pred = elastic_net.predict(X6_test_transformed)

# Calculate the mean squared error
mse = metrics.mean_squared_error(y6_test, y6_pred)

print(f"Training R-squared: {train_score}")
print(f"Test R-squared: {test_score}")
print(f"Mean Squared Error: {mse}")
# Out:
# Training R-squared: 0.9392290720297757
# Test R-squared: 0.8204193140520909
# Mean Squared Error: 1008852676.9456257
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.347e+11, tolerance: 1.041e+09
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# **Friends don't let friends Grid Search... but I did use it to find the best parameters**
#
# Best alpha = .01
#
# Best l1_ratio = .7

# %%
df6 = pd.read_csv('../datasets/df5.csv')
df6 = df6.dropna()
df6_X = df6.drop(columns=['Unnamed: 0', 'Id', 'SalePrice'])
df6_y = df6['SalePrice']
X6_train, X6_test, y6_train, y6_test = train_test_split(df6_X, df6_y, test_size=0.2, random_state=24)
df6_train_str = list(X6_train.select_dtypes(include=['object']).columns)
df6_test_str = list(X6_test.select_dtypes(include=['object']).columns)
df6_train_num = list(X6_train.select_dtypes(include=['int', 'float']).columns)
df6_test_num = list(X6_test.select_dtypes(include=['int', 'float']).columns)

# Create a ColumnTransformer with PolynomialFeatures, StandardScaler, and OneHotEncoder
ct = ColumnTransformer([
    ('poly', PolynomialFeatures(include_bias=False), df6_train_num),
    ('scaler', StandardScaler(), df6_train_num),
    ('oh', OneHotEncoder(sparse_output=False, handle_unknown= 'ignore', drop='first'), df6_train_str)
], remainder='passthrough')

# Fit and transform the training data using the ColumnTransformer
X6_train_transformed = ct.fit_transform(X6_train)

# Transform the test data using the fitted ColumnTransformer
X6_test_transformed = ct.transform(X6_test)

# Create an ElasticNet model
elastic_net = ElasticNet()
param_grid = {
    'alpha': [0.01, 0.1, 1.0, 10.0],      # Values of alpha to test
    'l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9]  # Values of l1_ratio to test
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=elastic_net, param_grid=param_grid, cv=5)

# Fit the GridSearchCV object to the training data
grid_search.fit(X6_train_transformed, y6_train)

# Get the best hyperparameters from the search
best_alpha = grid_search.best_params_['alpha']
best_l1_ratio = grid_search.best_params_['l1_ratio']

print(f"Best alpha: {best_alpha}")
print(f"Best l1_ratio: {best_l1_ratio}")
# Out:
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.819e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.704e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.550e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.591e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.570e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.782e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.662e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.514e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.552e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.530e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.736e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.611e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.468e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.503e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.480e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.674e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.542e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.408e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.436e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.414e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.573e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.434e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.319e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.322e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.309e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.162e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.089e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.903e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.940e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.963e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.130e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.053e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.869e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.909e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.925e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.083e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.001e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.820e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.862e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.870e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.007e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.915e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.740e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.785e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.781e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.835e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.722e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.566e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.608e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.588e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.349e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.293e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.114e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.178e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.338e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.281e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.091e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.166e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.319e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.261e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.071e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.087e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.145e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.284e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.224e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.034e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.056e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.105e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.176e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.918e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.954e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.979e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.385e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.333e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.143e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.144e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.220e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.384e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.332e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.142e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.143e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.218e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.382e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.329e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.140e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.141e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.215e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.378e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.324e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.136e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.139e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.210e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.355e+11, tolerance: 8.204e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.299e+11, tolerance: 8.038e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.110e+11, tolerance: 7.850e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.120e+11, tolerance: 8.013e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.185e+11, tolerance: 7.760e+08
#   model = cd_fast.enet_coordinate_descent(
# Best alpha: 0.01
# Best l1_ratio: 0.7
# C:\Users\kaitl\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.295e+11, tolerance: 9.967e+08
#   model = cd_fast.enet_coordinate_descent(
